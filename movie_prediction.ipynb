# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(".\\Data.csv")
df.head()
# Out:
#    budget_million  worldwide_gross_million  genre  director_experience  \
# 0             100                      202      4                    3
# 1             100                      337      3                    5
# 2             295                      384      0                    7
# 3             250                      761      0                    6
# 4              67                      261      1                    3
#
#    runtime_min  release_season  sequel  success
# 0          115               2       1        0
# 1          157               1       1        1
# 2          154               0       1        0
# 3          119               0       1        1
# 4           99               0       1        1

# %%
x = df.drop(["success"] ,axis=1)
y = df["success"]

# %%
x = np.array(x)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(x , y , test_size=0.2)

# %% [markdown]
# Model for test

# %%
from sklearn.ensemble import RandomForestClassifier
model_test = RandomForestClassifier(max_depth=7 , min_samples_split=4)
model_test.fit(X_test ,Y_test)
# Out:
# RandomForestClassifier(max_depth=7, min_samples_split=4)

# %% [markdown]
# Model for result

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(max_depth=7 , min_samples_split=4)
model.fit(x ,y)
# Out:
# RandomForestClassifier(max_depth=7, min_samples_split=4)

# %%
Y_pred_train = model_test.predict(X_train)
Y_pred_test = model_test.predict(X_test)

# %%
w = df["worldwide_gross_million"]
plt.plot(w, y , "o")
plt.show()

# %%
from sklearn.metrics import roc_auc_score , accuracy_score , confusion_matrix , precision_score , recall_score
rac = roc_auc_score(Y_test ,Y_pred_test)
rac
# Out:
# 1.0

# %%
acc = accuracy_score(Y_test, Y_pred_test)
acc
# Out:
# 1.0

# %%
c = confusion_matrix(Y_test, Y_pred_test)
c
# Out:
# array([[7, 0],
#        [0, 6]])

# %%
r = recall_score(Y_test, Y_pred_test)
r
# Out:
# 1.0

# %%
p = precision_score(Y_test, Y_pred_test)
p
# Out:
# 1.0

# %% [markdown]
# Feature importances

# %%
print(f"\nBudget : %{(model.feature_importances_[0]*100)}")
print(f"\nworldwide_gross_million : %{(model.feature_importances_[1]*100)}")
print(f"\ngenre : %{(model.feature_importances_[2]*100)}")
print(f"\ndirector_experience : %{(model.feature_importances_[3]*100)}")
print(f"\nruntime_min : %{(model.feature_importances_[4]*100)}")
print(f"\nrelease_season : %{(model.feature_importances_[5]*100)}")
print(f"\nsequel : %{(model.feature_importances_[6]*100)}")
# Out:
# Budget : %14.222187073577624
#
# worldwide_gross_million : %45.537052344817276
#
# genre : %4.772442965792398
#
# director_experience : %9.434830995262917
#
# runtime_min : %15.866992140177736
#
# release_season : %5.77486158131998
#
# sequel : %4.391632899052077

# %%
dr = {
    "budget_million" : np.random.randint(100,300),
    "worldwide_gross_million" : np.random.randint(250,1000),
    "genre" : np.random.randint(1,7),
    "director_experience" : np.random.randint(1,10),
    "runtime_min" : np.random.randint(90,180),
    "release_season" : np.random.randint(0,5),
    "sequel" : np.random.randint(0,2)  
}
dfr = pd.DataFrame(dr, index=[1])

# %%
result = model.predict(dfr)
if result == [1] :
    print("Your Movie will succefull in hollywood")
else :
    print("Your Movie will unsuccefull in hollywood")
# Out:
# Your Movie will succefull in hollywood
# c:\Users\mahan.ly\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
